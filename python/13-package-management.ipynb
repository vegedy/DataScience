# %% [markdown]
# # Pip

# %%
# %pip --version
# Out:
# pip 25.2 from c:\Users\bzenz\AppData\Local\miniconda3\envs\py312\Lib\site-packages\pip (python 3.12)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip help
# Out:
# Usage:
#   c:\Users\bzenz\AppData\Local\miniconda3\envs\py312\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   lock                        Generate a lock file.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --debug                     Let unhandled exceptions propagate outside the
#                               main subroutine, instead of logging them to
#                               stderr.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   --require-virtualenv        Allow pip to only run in a virtual environment;
#                               exit with an error otherwise.
#   --python <python>           Run pip with the specified Python interpreter.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --no-input                  Disable prompting for input.
#   --keyring-provider <keyring_provider>
#                               Enable the credential lookup via the keyring
#                               library if user input is allowed. Specify which
#                               mechanism to use [auto, disabled, import,
#                               subprocess]. (default: auto)
#   --proxy <proxy>             Specify a proxy in the form
#                               scheme://[user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum attempts to establish a new HTTP
#                               connection. (default: 5)
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to PEM-encoded CA certificate bundle. If
#                               provided, overrides the default. See 'SSL
#                               Certificate Verification' in pip documentation
#                               for more information.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.
#   --resume-retries <resume_retries>
#                               Maximum attempts to resume or restart an
#                               incomplete download. (default: 5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#python -m pip install --upgrade pip

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# certifi                 2025.8.3
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.16
# decorator               5.2.1
# exceptiongroup          1.3.0
# executing               2.2.1
# fonttools               4.59.2
# importlib_metadata      8.7.0
# ipykernel               6.30.1
# ipython                 9.5.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# joblib                  1.5.2
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# kiwisolver              1.4.9
# matplotlib              3.9.1
# matplotlib-inline       0.1.7
# munkres                 1.1.4
# nest_asyncio            1.6.0
# numpy                   2.3.3
# packaging               25.0
# pandas                  2.3.2
# parso                   0.8.5
# patsy                   1.0.1
# pickleshare             0.7.5
# pillow                  11.3.0
# pip                     25.2
# platformdirs            4.4.0
# ply                     3.11
# prompt_toolkit          3.0.52
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.2
# pyparsing               3.2.3
# PyQt5                   5.15.11
# PyQt5_sip               12.17.0
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pywin32                 311
# pyzmq                   27.1.0
# scikit-learn            1.7.2
# scipy                   1.16.1
# seaborn                 0.13.2
# setuptools              80.9.0
# sip                     6.10.0
# six                     1.17.0
# stack_data              0.6.3
# statsmodels             0.14.5
# threadpoolctl           3.6.0
# toml                    0.10.2
# tomli                   2.2.1
# tornado                 6.5.2
# traitlets               5.14.3
# typing_extensions       4.15.0
# tzdata                  2025.2
# unicodedata2            16.0.0
# wcwidth                 0.2.13
# wheel                   0.45.1
# zipp                    3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\bzenz\appdata\local\miniconda3\envs\py312\lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip uninstall numpy

# %%
# %pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
# =========================================================
#
# 1. This LICENSE AGREEMENT is between the Matplotlib Development Team
# ("MDT"), and the Individual or Organization ("Licensee") accessing and
# otherwise using matplotlib software in source or binary form and its
# associated documentation.
#
# 2. Subject to the terms and conditions of this License Agreement, MDT
# hereby grants Licensee a nonexclusive, royalty-free, world-wide license
# to reproduce, analyze, test, perform and/or display publicly, prepare
# derivative works, distribute, and otherwise use matplotlib
# alone or in any derivative version, provided, however, that MDT's
# License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
# 2012- Matplotlib Development Team; All Rights Reserved" are retained in
# matplotlib  alone or in any derivative version prepared by
# Licensee.
#
# 3. In the event Licensee prepares a derivative work that is based on or
# incorporates matplotlib or any part thereof, and wants to
# make the derivative work available to others as provided herein, then
# Licensee hereby agrees to include in any such work a brief summary of
# the changes made to matplotlib .
#
# 4. MDT is making matplotlib available to Licensee on an "AS
# IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
# IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
# DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
# FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
# WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
# 5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#  FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
# LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
# MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
# THE POSSIBILITY THEREOF.
#
# 6. This License Agreement will automatically terminate upon a material
# breach of its terms and conditions.
#
# 7. Nothing in this License Agreement shall be deemed to create any
# relationship of agency, partnership, or joint venture between MDT and
# Licensee.  This License Agreement does not grant permission to use MDT
# trademarks or trade name in a trademark sense to endorse or promote
# products or services of Licensee, or any third party.
#
# 8. By copying, installing or otherwise using matplotlib ,
# Licensee agrees to be bound by the terms and conditions of this License
# Agreement.
#
# License agreement for matplotlib versions prior to 1.3.0
# ========================================================
#
# 1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
# Individual or Organization ("Licensee") accessing and otherwise using
# matplotlib software in source or binary form and its associated
# documentation.
#
# 2. Subject to the terms and conditions of this License Agreement, JDH
# hereby grants Licensee a nonexclusive, royalty-free, world-wide license
# to reproduce, analyze, test, perform and/or display publicly, prepare
# derivative works, distribute, and otherwise use matplotlib
# alone or in any derivative version, provided, however, that JDH's
# License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
# 2002-2011 John D. Hunter; All Rights Reserved" are retained in
# matplotlib  alone or in any derivative version prepared by
# Licensee.
#
# 3. In the event Licensee prepares a derivative work that is based on or
# incorporates matplotlib  or any part thereof, and wants to
# make the derivative work available to others as provided herein, then
# Licensee hereby agrees to include in any such work a brief summary of
# the changes made to matplotlib.
#
# 4. JDH is making matplotlib  available to Licensee on an "AS
# IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
# IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
# DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
# FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
# WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
# 5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#  FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
# LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
# MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
# THE POSSIBILITY THEREOF.
#
# 6. This License Agreement will automatically terminate upon a material
# breach of its terms and conditions.
#
# 7. Nothing in this License Agreement shall be deemed to create any
# relationship of agency, partnership, or joint venture between JDH and
# Licensee.  This License Agreement does not grant permission to use JDH
# trademarks or trade name in a trademark sense to endorse or promote
# products or services of Licensee, or any third party.
#
# 8. By copying, installing or otherwise using matplotlib,
# Licensee agrees to be bound by the terms and conditions of this License
# Agreement.
# Location: c:\Users\bzenz\AppData\Local\miniconda3\envs\py312\Lib\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: seaborn
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Conda

# %%
# %conda --version
# Out:
# conda 25.7.0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda install seaborn
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\bzenz\AppData\Local\miniconda3\envs\py312
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.13.2             |       hd8ed1ab_3           7 KB  conda-forge
#     seaborn-base-0.13.2        |     pyhd8ed1ab_3         223 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         229 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            conda-forge/noarch::seaborn-0.13.2-hd8ed1ab_3
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.2-pyhd8ed1ab_3
#
#
#
# Downloading and Extracting Packages: ...working...
# seaborn-base-0.13.2  | 223 KB    |            |   0%
#
# seaborn-0.13.2       | 7 KB      |            |   0%
#
# seaborn-0.13.2       | 7 KB      | ########## | 100%
# seaborn-base-0.13.2  | 223 KB    | 7          |   7%
#
# seaborn-0.13.2       | 7 KB      | ########## | 100%
#
# seaborn-0.13.2       | 7 KB      | ########## | 100%
# seaborn-base-0.13.2  | 223 KB    | ########## | 100%
# seaborn-base-0.13.2  | 223 KB    | ########## | 100%
# seaborn-base-0.13.2  | 223 KB    | ########## | 100%
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda update seaborn
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda list
# Out:
# # packages in environment at c:\Users\bzenz\AppData\Local\miniconda3\envs\py312:
# #
# # Name                     Version                Build                  Channel
# _openmp_mutex              4.5                    2_gnu                  conda-forge
# _python_abi3_support       1.0                    hd8ed1ab_2             conda-forge
# archspec                   0.2.5                  pyhd8ed1ab_0           conda-forge
# asttokens                  3.0.0                  pyhd8ed1ab_1           conda-forge
# boltons                    25.0.0                 pyhd8ed1ab_0           conda-forge
# brotli                     1.1.0                  hfd05255_4             conda-forge
# brotli-bin                 1.1.0                  hfd05255_4             conda-forge
# brotli-python              1.1.0                  py312hbb81ca0_4        conda-forge
# bzip2                      1.0.8                  h0ad9c76_8             conda-forge
# ca-certificates            2025.8.3               h4c7d964_0             conda-forge
# certifi                    2025.8.3               pyhd8ed1ab_0           conda-forge
# cffi                       1.17.1                 py312he06e257_1        conda-forge
# charset-normalizer         3.4.3                  pyhd8ed1ab_0           conda-forge
# colorama                   0.4.6                  pyhd8ed1ab_1           conda-forge
# comm                       0.2.3                  pyhe01879c_0           conda-forge
# conda                      23.9.0                 py312h2e8e312_2        conda-forge
# conda-package-handling     2.4.0                  pyh7900ff3_2           conda-forge
# conda-package-streaming    0.12.0                 pyhd8ed1ab_0           conda-forge
# contourpy                  1.3.3                  py312hf90b1b7_2        conda-forge
# cpython                    3.12.11                py312hd8ed1ab_0        conda-forge
# cryptography               45.0.7                 py312h84d000f_1        conda-forge
# cycler                     0.12.1                 pyhd8ed1ab_1           conda-forge
# debugpy                    1.8.16                 py312ha1a9051_1        conda-forge
# decorator                  5.2.1                  pyhd8ed1ab_0           conda-forge
# exceptiongroup             1.3.0                  pyhd8ed1ab_0           conda-forge
# executing                  2.2.1                  pyhd8ed1ab_0           conda-forge
# fonttools                  4.59.2                 py312h05f76fc_0        conda-forge
# freetype                   2.14.0                 h57928b3_1             conda-forge
# glib                       2.86.0                 ha3795fc_0             conda-forge
# glib-tools                 2.86.0                 he647baa_0             conda-forge
# gst-plugins-base           1.24.11                h3fe0a9e_0             conda-forge
# gstreamer                  1.24.11                h233a61a_0             conda-forge
# h2                         4.3.0                  pyhcf101f3_0           conda-forge
# hpack                      4.1.0                  pyhd8ed1ab_0           conda-forge
# hyperframe                 6.1.0                  pyhd8ed1ab_0           conda-forge
# icu                        75.1                   he0c23c2_0             conda-forge
# idna                       3.10                   pyhd8ed1ab_1           conda-forge
# importlib-metadata         8.7.0                  pyhe01879c_1           conda-forge
# ipykernel                  6.30.1                 pyh3521513_0           conda-forge
# ipython                    9.5.0                  pyh6be1c34_0           conda-forge
# ipython_pygments_lexers    1.1.1                  pyhd8ed1ab_0           conda-forge
# jedi                       0.19.2                 pyhd8ed1ab_1           conda-forge
# joblib                     1.5.2                  pyhd8ed1ab_0           conda-forge
# jsonpatch                  1.33                   pyhd8ed1ab_1           conda-forge
# jsonpointer                3.0.0                  py312h2e8e312_2        conda-forge
# jupyter_client             8.6.3                  pyhd8ed1ab_1           conda-forge
# jupyter_core               5.8.1                  pyh5737063_0           conda-forge
# kiwisolver                 1.4.9                  py312h78d62e6_1        conda-forge
# krb5                       1.21.3                 hdf4eb48_0             conda-forge
# lcms2                      2.17                   hbcf6048_0             conda-forge
# lerc                       4.0.0                  h6470a55_1             conda-forge
# libblas                    3.9.0                  35_h5709861_mkl        conda-forge
# libbrotlicommon            1.1.0                  hfd05255_4             conda-forge
# libbrotlidec               1.1.0                  hfd05255_4             conda-forge
# libbrotlienc               1.1.0                  hfd05255_4             conda-forge
# libcblas                   3.9.0                  35_h2a3cdd5_mkl        conda-forge
# libclang13                 21.1.0                 default_ha2db4b5_1     conda-forge
# libdeflate                 1.24                   h76ddb4d_0             conda-forge
# libexpat                   2.7.1                  hac47afa_0             conda-forge
# libffi                     3.4.6                  h537db12_1             conda-forge
# libfreetype                2.14.0                 h57928b3_1             conda-forge
# libfreetype6               2.14.0                 hdbac1cb_1             conda-forge
# libgcc                     15.1.0                 h1383e82_5             conda-forge
# libglib                    2.86.0                 h5f26cbf_0             conda-forge
# libgomp                    15.1.0                 h1383e82_5             conda-forge
# libhwloc                   2.12.1                 default_h64bd3f2_1001  conda-forge
# libiconv                   1.18                   hc1393d2_2             conda-forge
# libintl                    0.22.5                 h5728263_3             conda-forge
# libintl-devel              0.22.5                 h5728263_3             conda-forge
# libjpeg-turbo              3.1.0                  h2466b09_0             conda-forge
# liblapack                  3.9.0                  35_hf9ab0e9_mkl        conda-forge
# liblzma                    5.8.1                  h2466b09_2             conda-forge
# libogg                     1.3.5                  h2466b09_1             conda-forge
# libpng                     1.6.50                 h7351971_1             conda-forge
# libsodium                  1.0.20                 hc70643c_0             conda-forge
# libsqlite                  3.50.4                 hf5d6505_0             conda-forge
# libtiff                    4.7.0                  h550210a_6             conda-forge
# libvorbis                  1.3.7                  h5112557_2             conda-forge
# libwebp-base               1.6.0                  h4d5522a_0             conda-forge
# libwinpthread              12.0.0.r4.gg4f2fc60ca  h57928b3_9             conda-forge
# libxcb                     1.17.0                 h0e4246c_0             conda-forge
# libxml2                    2.14.6                 ha29bfb0_1             conda-forge
# libxml2-16                 2.14.6                 h06f855e_1             conda-forge
# libzlib                    1.3.1                  h2466b09_2             conda-forge
# llvm-openmp                20.1.8                 hfa2b4ca_2             conda-forge
# matplotlib                 3.9.1                  py312h2e8e312_1        conda-forge
# matplotlib-base            3.9.1                  py312h90004f6_2        conda-forge
# matplotlib-inline          0.1.7                  pyhd8ed1ab_1           conda-forge
# menuinst                   1.4.20                 py312hbb81ca0_1        conda-forge
# mkl                        2024.2.2               h57928b3_16            conda-forge
# munkres                    1.1.4                  pyhd8ed1ab_1           conda-forge
# nest-asyncio               1.6.0                  pyhd8ed1ab_1           conda-forge
# numpy                      2.3.3                  py312ha72d056_0        conda-forge
# openjpeg                   2.5.3                  h24db6dd_1             conda-forge
# openssl                    3.5.2                  h725018a_0             conda-forge
# packaging                  25.0                   pyh29332c3_1           conda-forge
# pandas                     2.3.2                  py312hc128f0a_0        conda-forge
# parso                      0.8.5                  pyhcf101f3_0           conda-forge
# patsy                      1.0.1                  pyhd8ed1ab_1           conda-forge
# pcre2                      10.46                  h3402e2f_0             conda-forge
# pickleshare                0.7.5                  pyhd8ed1ab_1004        conda-forge
# pillow                     11.3.0                 py312hfb502af_1        conda-forge
# pip                        25.2                   pyh8b19718_0           conda-forge
# platformdirs               4.4.0                  pyhcf101f3_0           conda-forge
# pluggy                     1.6.0                  pyhd8ed1ab_0           conda-forge
# ply                        3.11                   pyhd8ed1ab_3           conda-forge
# prompt-toolkit             3.0.52                 pyha770c72_0           conda-forge
# psutil                     7.0.0                  py312he06e257_1        conda-forge
# pthread-stubs              0.4                    h0e40799_1002          conda-forge
# pure_eval                  0.2.3                  pyhd8ed1ab_1           conda-forge
# pycosat                    0.6.6                  py312h4389bb4_2        conda-forge
# pycparser                  2.22                   pyh29332c3_1           conda-forge
# pygments                   2.19.2                 pyhd8ed1ab_0           conda-forge
# pyopenssl                  25.1.0                 pyhd8ed1ab_0           conda-forge
# pyparsing                  3.2.3                  pyhe01879c_2           conda-forge
# pyqt                       5.15.11                py312he11f4ca_1        conda-forge
# pyqt5-sip                  12.17.0                py312h275cf98_1        conda-forge
# pysocks                    1.7.1                  pyh09c184e_7           conda-forge
# python                     3.12.11                h3f84c4b_0_cpython     conda-forge
# python-dateutil            2.9.0.post0            pyhe01879c_2           conda-forge
# python-gil                 3.12.11                hd8ed1ab_0             conda-forge
# python-tzdata              2025.2                 pyhd8ed1ab_0           conda-forge
# python_abi                 3.12                   8_cp312                conda-forge
# pytz                       2025.2                 pyhd8ed1ab_0           conda-forge
# pywin32                    311                    py312h829343e_1        conda-forge
# pyzmq                      27.1.0                 py312hbb5da91_0        conda-forge
# qhull                      2020.2                 hc790b64_5             conda-forge
# qt-main                    5.15.15                hb098fff_5             conda-forge
# requests                   2.32.5                 pyhd8ed1ab_0           conda-forge
# ruamel.yaml                0.17.40                py312he70551f_0        conda-forge
# ruamel.yaml.clib           0.2.12                 py312he06e257_1        conda-forge
# scikit-learn               1.7.2                  py312h91ac024_0        conda-forge
# scipy                      1.16.1                 py312h33376e8_1        conda-forge
# seaborn                    0.13.2                 hd8ed1ab_3             conda-forge
# seaborn-base               0.13.2                 pyhd8ed1ab_3           conda-forge
# setuptools                 80.9.0                 pyhff2d567_0           conda-forge
# sip                        6.10.0                 py312h275cf98_0        conda-forge
# six                        1.17.0                 pyhe01879c_1           conda-forge
# stack_data                 0.6.3                  pyhd8ed1ab_1           conda-forge
# statsmodels                0.14.5                 py312h196c9fc_0        conda-forge
# tbb                        2021.13.0              h18a62a1_3             conda-forge
# threadpoolctl              3.6.0                  pyhecae5ae_0           conda-forge
# tk                         8.6.13                 h2c6b04d_2             conda-forge
# toml                       0.10.2                 pyhd8ed1ab_1           conda-forge
# tomli                      2.2.1                  pyhe01879c_2           conda-forge
# tornado                    6.5.2                  py312he06e257_1        conda-forge
# tqdm                       4.67.1                 pyhd8ed1ab_1           conda-forge
# traitlets                  5.14.3                 pyhd8ed1ab_1           conda-forge
# truststore                 0.10.3                 pyhe01879c_0           conda-forge
# typing-extensions          4.15.0                 h396c80c_0             conda-forge
# typing_extensions          4.15.0                 pyhcf101f3_0           conda-forge
# tzdata                     2025b                  h78e105d_0             conda-forge
# ucrt                       10.0.26100.0           h57928b3_0             conda-forge
# unicodedata2               16.0.0                 py312he06e257_1        conda-forge
# urllib3                    2.5.0                  pyhd8ed1ab_0           conda-forge
# vc                         14.3                   h41ae7f8_31            conda-forge
# vc14_runtime               14.44.35208            h818238b_31            conda-forge
# vcomp14                    14.44.35208            h818238b_31            conda-forge
# wcwidth                    0.2.13                 pyhd8ed1ab_1           conda-forge
# wheel                      0.45.1                 pyhd8ed1ab_1           conda-forge
# win_inet_pton              1.1.0                  pyh7428d3b_8           conda-forge
# xorg-libxau                1.0.12                 h0e40799_0             conda-forge
# xorg-libxdmcp              1.1.5                  h0e40799_0             conda-forge
# zeromq                     4.3.5                  h5bddc39_9             conda-forge
# zipp                       3.23.0                 pyhd8ed1ab_0           conda-forge
# zstandard                  0.24.0                 py312ha680012_1        conda-forge
# zstd                       1.5.7                  hbeecb71_2             conda-forge
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#%conda uninstall numpy

# %%
# %conda search pandas
# Out:
# 3 channel Terms of Service accepted
# Loading channels: done
# # Name                       Version           Build  Channel
# pandas                        0.17.0     np110py27_0  conda-forge
# pandas                        0.17.0     np110py34_0  conda-forge
# pandas                        0.17.0     np110py35_0  conda-forge
# pandas                        0.17.0     np111py27_0  conda-forge
# pandas                        0.17.0     np111py34_0  conda-forge
# pandas                        0.17.0     np111py35_0  conda-forge
# pandas                        0.17.1     np110py27_0  conda-forge
# pandas                        0.17.1     np110py34_0  conda-forge
# pandas                        0.17.1     np110py35_0  conda-forge
# pandas                        0.17.1     np111py27_0  conda-forge
# pandas                        0.17.1     np111py34_0  conda-forge
# pandas                        0.17.1     np111py35_0  conda-forge
# pandas                        0.18.1     np110py27_0  conda-forge
# pandas                        0.18.1     np110py27_1  conda-forge
# pandas                        0.18.1     np110py34_0  conda-forge
# pandas                        0.18.1     np110py34_1  conda-forge
# pandas                        0.18.1     np110py35_0  conda-forge
# pandas                        0.18.1     np110py35_1  conda-forge
# pandas                        0.18.1     np111py27_0  conda-forge
# pandas                        0.18.1     np111py27_1  conda-forge
# pandas                        0.18.1     np111py34_0  conda-forge
# pandas                        0.18.1     np111py34_1  conda-forge
# pandas                        0.18.1     np111py35_0  conda-forge
# pandas                        0.18.1     np111py35_1  conda-forge
# pandas                        0.19.0     np110py27_0  conda-forge
# pandas                        0.19.0     np110py34_0  conda-forge
# pandas                        0.19.0     np110py35_0  conda-forge
# pandas                        0.19.0     np111py27_0  conda-forge
# pandas                        0.19.0     np111py34_0  conda-forge
# pandas                        0.19.0     np111py35_0  conda-forge
# pandas                        0.19.1     np110py27_0  conda-forge
# pandas                        0.19.1     np110py35_0  conda-forge
# pandas                        0.19.1     np111py27_0  conda-forge
# pandas                        0.19.1     np111py34_0  conda-forge
# pandas                        0.19.1     np111py35_0  conda-forge
# pandas                        0.19.2     np110py27_0  conda-forge
# pandas                        0.19.2     np110py27_1  conda-forge
# pandas                        0.19.2     np110py34_0  conda-forge
# pandas                        0.19.2     np110py34_1  conda-forge
# pandas                        0.19.2     np110py35_0  conda-forge
# pandas                        0.19.2     np110py35_1  conda-forge
# pandas                        0.19.2     np111py27_0  conda-forge
# pandas                        0.19.2     np111py27_1  conda-forge
# pandas                        0.19.2     np111py34_0  conda-forge
# pandas                        0.19.2     np111py34_1  conda-forge
# pandas                        0.19.2     np111py35_0  conda-forge
# pandas                        0.19.2     np111py35_1  conda-forge
# pandas                        0.19.2     np111py36_0  conda-forge
# pandas                        0.19.2     np111py36_1  conda-forge
# pandas                        0.19.2     np112py27_1  conda-forge
# pandas                        0.19.2     np112py35_1  conda-forge
# pandas                        0.19.2     np112py36_1  conda-forge
# pandas                        0.20.0     np111py27_1  conda-forge
# pandas                        0.20.0     np111py35_1  conda-forge
# pandas                        0.20.0     np111py36_1  conda-forge
# pandas                        0.20.0     np112py27_1  conda-forge
# pandas                        0.20.0     np112py35_1  conda-forge
# pandas                        0.20.0     np112py36_1  conda-forge
# pandas                        0.20.1     np111py27_0  conda-forge
# pandas                        0.20.1     np111py35_0  conda-forge
# pandas                        0.20.1     np111py36_0  conda-forge
# pandas                        0.20.1     np112py27_0  conda-forge
# pandas                        0.20.1     np112py35_0  conda-forge
# pandas                        0.20.1     np112py36_0  conda-forge
# pandas                        0.20.2     np111py27_0  conda-forge
# pandas                        0.20.2     np111py27_1  conda-forge
# pandas                        0.20.2     np111py35_0  conda-forge
# pandas                        0.20.2     np111py35_1  conda-forge
# pandas                        0.20.2     np111py36_0  conda-forge
# pandas                        0.20.2     np111py36_1  conda-forge
# pandas                        0.20.2     np112py27_0  conda-forge
# pandas                        0.20.2     np112py27_1  conda-forge
# pandas                        0.20.2     np112py35_0  conda-forge
# pandas                        0.20.2     np112py35_1  conda-forge
# pandas                        0.20.2     np112py36_0  conda-forge
# pandas                        0.20.2     np112py36_1  conda-forge
# pandas                        0.20.2     np113py27_1  conda-forge
# pandas                        0.20.2     np113py35_1  conda-forge
# pandas                        0.20.2     np113py36_1  conda-forge
# pandas                        0.20.3     np111py27_0  conda-forge
# pandas                        0.20.3     np111py35_0  conda-forge
# pandas                        0.20.3     np111py36_0  conda-forge
# pandas                        0.20.3     np112py27_0  conda-forge
# pandas                        0.20.3     np112py35_0  conda-forge
# pandas                        0.20.3     np112py36_0  conda-forge
# pandas                        0.20.3     np113py27_0  conda-forge
# pandas                        0.20.3     np113py35_0  conda-forge
# pandas                        0.20.3     np113py36_0  conda-forge
# pandas                        0.20.3          py27_1  conda-forge
# pandas                        0.20.3  py27he04484b_2  pkgs/main
# pandas                        0.20.3          py34_1  conda-forge
# pandas                        0.20.3          py35_1  conda-forge
# pandas                        0.20.3  py35he2ce742_2  pkgs/main
# pandas                        0.20.3          py36_1  conda-forge
# pandas                        0.20.3  py36hce827b7_2  pkgs/main
# pandas                        0.21.0          py27_0  conda-forge
# pandas                        0.21.0  py27h3b50df0_1  pkgs/main
# pandas                        0.21.0  py27he42dcfb_0  pkgs/main
# pandas                        0.21.0          py35_0  conda-forge
# pandas                        0.21.0  py35h0510043_1  pkgs/main
# pandas                        0.21.0  py35haac58f6_0  pkgs/main
# pandas                        0.21.0          py36_0  conda-forge
# pandas                        0.21.0  py36ha94a700_0  pkgs/main
# pandas                        0.21.0  py36he09d4dd_1  pkgs/main
# pandas                        0.21.1          py27_0  conda-forge
# pandas                        0.21.1  py27h5a33001_0  pkgs/main
# pandas                        0.21.1          py35_0  conda-forge
# pandas                        0.21.1  py35h047fa9f_0  pkgs/main
# pandas                        0.21.1          py36_0  conda-forge
# pandas                        0.21.1  py36h047fa9f_0  pkgs/main
# pandas                        0.22.0          py27_0  conda-forge
# pandas                        0.22.0          py27_1  conda-forge
# pandas                        0.22.0  py27hc56fc5f_0  pkgs/main
# pandas                        0.22.0          py35_0  conda-forge
# pandas                        0.22.0          py35_1  conda-forge
# pandas                        0.22.0  py35h6538335_0  pkgs/main
# pandas                        0.22.0          py36_0  conda-forge
# pandas                        0.22.0          py36_1  conda-forge
# pandas                        0.22.0  py36h6538335_0  pkgs/main
# pandas                        0.23.0          py27_0  conda-forge
# pandas                        0.23.0          py27_1  conda-forge
# pandas                        0.23.0  py27h39f3610_0  pkgs/main
# pandas                        0.23.0          py35_0  conda-forge
# pandas                        0.23.0          py35_1  conda-forge
# pandas                        0.23.0  py35h830ac7b_0  pkgs/main
# pandas                        0.23.0          py36_0  conda-forge
# pandas                        0.23.0          py36_1  conda-forge
# pandas                        0.23.0  py36h830ac7b_0  pkgs/main
# pandas                        0.23.1          py27_0  conda-forge
# pandas                        0.23.1  py27h39f3610_0  pkgs/main
# pandas                        0.23.1          py35_0  conda-forge
# pandas                        0.23.1  py35h830ac7b_0  pkgs/main
# pandas                        0.23.1          py36_0  conda-forge
# pandas                        0.23.1  py36h830ac7b_0  pkgs/main
# pandas                        0.23.2          py27_0  conda-forge
# pandas                        0.23.2  py27h39f3610_0  pkgs/main
# pandas                        0.23.2          py35_0  conda-forge
# pandas                        0.23.2          py36_0  conda-forge
# pandas                        0.23.2  py36h830ac7b_0  pkgs/main
# pandas                        0.23.2  py37h830ac7b_0  pkgs/main
# pandas                        0.23.3          py27_0  conda-forge
# pandas                        0.23.3  py27h39f3610_0  pkgs/main
# pandas                        0.23.3  py27h39f3610_1  conda-forge
# pandas                        0.23.3          py35_0  conda-forge
# pandas                        0.23.3  py35h830ac7b_0  pkgs/main
# pandas                        0.23.3  py35h830ac7b_1  conda-forge
# pandas                        0.23.3          py36_0  conda-forge
# pandas                        0.23.3  py36h830ac7b_0  pkgs/main
# pandas                        0.23.3  py36h830ac7b_1  conda-forge
# pandas                        0.23.3  py37h830ac7b_0  pkgs/main
# pandas                        0.23.4  py27h39f3610_0  conda-forge
# pandas                        0.23.4  py27h39f3610_0  pkgs/main
# pandas                        0.23.4 py27h39f3610_1000  conda-forge
# pandas                        0.23.4  py35h830ac7b_0  conda-forge
# pandas                        0.23.4  py35h830ac7b_0  pkgs/main
# pandas                        0.23.4  py36h830ac7b_0  conda-forge
# pandas                        0.23.4  py36h830ac7b_0  pkgs/main
# pandas                        0.23.4 py36h830ac7b_1000  conda-forge
# pandas                        0.23.4  py37h830ac7b_0  conda-forge
# pandas                        0.23.4  py37h830ac7b_0  pkgs/main
# pandas                        0.23.4 py37h830ac7b_1000  conda-forge
# pandas                        0.24.0  py27hc56fc5f_0  conda-forge
# pandas                        0.24.0  py27hc56fc5f_0  pkgs/main
# pandas                        0.24.0  py36h6538335_0  conda-forge
# pandas                        0.24.0  py36ha925a31_0  pkgs/main
# pandas                        0.24.0  py37h6538335_0  conda-forge
# pandas                        0.24.0  py37ha925a31_0  pkgs/main
# pandas                        0.24.1  py27hc56fc5f_0  conda-forge
# pandas                        0.24.1  py27hc56fc5f_0  pkgs/main
# pandas                        0.24.1  py36h6538335_0  conda-forge
# pandas                        0.24.1  py36ha925a31_0  pkgs/main
# pandas                        0.24.1  py37h6538335_0  conda-forge
# pandas                        0.24.1  py37ha925a31_0  pkgs/main
# pandas                        0.24.2  py27h0e003f4_0  conda-forge
# pandas                        0.24.2  py27hc56fc5f_0  conda-forge
# pandas                        0.24.2  py27hc56fc5f_0  pkgs/main
# pandas                        0.24.2  py36h6538335_0  conda-forge
# pandas                        0.24.2  py36ha925a31_0  pkgs/main
# pandas                        0.24.2  py36he350917_0  conda-forge
# pandas                        0.24.2  py36he350917_1  conda-forge
# pandas                        0.24.2  py37h6538335_0  conda-forge
# pandas                        0.24.2  py37ha925a31_0  pkgs/main
# pandas                        0.24.2  py37he350917_0  conda-forge
# pandas                        0.24.2  py37he350917_1  conda-forge
# pandas                        0.24.2  py38he350917_1  conda-forge
# pandas                        0.25.0  py36ha925a31_0  pkgs/main
# pandas                        0.25.0  py36he350917_0  conda-forge
# pandas                        0.25.0  py37ha925a31_0  pkgs/main
# pandas                        0.25.0  py37he350917_0  conda-forge
# pandas                        0.25.1  py36ha925a31_0  pkgs/main
# pandas                        0.25.1  py36he350917_0  conda-forge
# pandas                        0.25.1  py37ha925a31_0  pkgs/main
# pandas                        0.25.1  py37he350917_0  conda-forge
# pandas                        0.25.2  py36ha925a31_0  pkgs/main
# pandas                        0.25.2  py36he350917_0  conda-forge
# pandas                        0.25.2  py37ha925a31_0  pkgs/main
# pandas                        0.25.2  py37he350917_0  conda-forge
# pandas                        0.25.3  py36ha925a31_0  pkgs/main
# pandas                        0.25.3  py36he350917_0  conda-forge
# pandas                        0.25.3  py37ha925a31_0  pkgs/main
# pandas                        0.25.3  py37he350917_0  conda-forge
# pandas                        0.25.3  py38ha925a31_0  pkgs/main
# pandas                        0.25.3  py38he350917_0  conda-forge
# pandas                         1.0.0  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.0  py36he350917_0  conda-forge
# pandas                         1.0.0  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.0  py37he350917_0  conda-forge
# pandas                         1.0.0  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.0  py38he350917_0  conda-forge
# pandas                         1.0.1  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.1  py36he350917_0  conda-forge
# pandas                         1.0.1  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.1  py37he350917_0  conda-forge
# pandas                         1.0.1  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.1  py38he350917_0  conda-forge
# pandas                         1.0.2  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.2  py36h5076640_0  conda-forge
# pandas                         1.0.2  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.2  py37h9b59f54_0  conda-forge
# pandas                         1.0.2  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.2  py38hbe40bda_0  conda-forge
# pandas                         1.0.3  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.3  py36h5076640_0  conda-forge
# pandas                         1.0.3  py36hcc50265_1  conda-forge
# pandas                         1.0.3  py37h3bbf574_1  conda-forge
# pandas                         1.0.3  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.3  py37h9b59f54_0  conda-forge
# pandas                         1.0.3  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.3  py38hbe40bda_0  conda-forge
# pandas                         1.0.3  py38he6e81aa_1  conda-forge
# pandas                         1.0.4  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.4  py36hcc50265_0  conda-forge
# pandas                         1.0.4  py37h3bbf574_0  conda-forge
# pandas                         1.0.4  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.4  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.4  py38he6e81aa_0  conda-forge
# pandas                         1.0.5  py36h47e9c7a_0  pkgs/main
# pandas                         1.0.5  py36hcc50265_0  conda-forge
# pandas                         1.0.5  py37h3bbf574_0  conda-forge
# pandas                         1.0.5  py37h47e9c7a_0  pkgs/main
# pandas                         1.0.5  py38h47e9c7a_0  pkgs/main
# pandas                         1.0.5  py38he6e81aa_0  conda-forge
# pandas                         1.1.0  py36h003fed8_0  conda-forge
# pandas                         1.1.0  py36ha925a31_0  pkgs/main
# pandas                         1.1.0  py37h1834ac0_0  conda-forge
# pandas                         1.1.0  py37ha925a31_0  pkgs/main
# pandas                         1.1.0  py38h7ae7562_0  conda-forge
# pandas                         1.1.0  py38ha925a31_0  pkgs/main
# pandas                         1.1.1  py36h003fed8_0  conda-forge
# pandas                         1.1.1  py36ha925a31_0  pkgs/main
# pandas                         1.1.1  py37h1834ac0_0  conda-forge
# pandas                         1.1.1  py37ha925a31_0  pkgs/main
# pandas                         1.1.1  py38h7ae7562_0  conda-forge
# pandas                         1.1.1  py38ha925a31_0  pkgs/main
# pandas                         1.1.2  py36h003fed8_0  conda-forge
# pandas                         1.1.2  py36ha925a31_0  pkgs/main
# pandas                         1.1.2  py37h1834ac0_0  conda-forge
# pandas                         1.1.2  py37ha925a31_0  pkgs/main
# pandas                         1.1.2  py38h7ae7562_0  conda-forge
# pandas                         1.1.2  py38ha925a31_0  pkgs/main
# pandas                         1.1.3  py36h003fed8_0  conda-forge
# pandas                         1.1.3  py36ha925a31_0  pkgs/main
# pandas                         1.1.3  py36hd7f5668_1  conda-forge
# pandas                         1.1.3  py36hd7f5668_2  conda-forge
# pandas                         1.1.3  py36hfcfa802_2  conda-forge
# pandas                         1.1.3  py37h06f6abc_2  conda-forge
# pandas                         1.1.3  py37h1834ac0_0  conda-forge
# pandas                         1.1.3  py37h414f9d2_1  conda-forge
# pandas                         1.1.3  py37h414f9d2_2  conda-forge
# pandas                         1.1.3  py37ha925a31_0  pkgs/main
# pandas                         1.1.3  py38h251f6bf_1  conda-forge
# pandas                         1.1.3  py38h251f6bf_2  conda-forge
# pandas                         1.1.3  py38h3ef910b_2  conda-forge
# pandas                         1.1.3  py38h7ae7562_0  conda-forge
# pandas                         1.1.3  py38ha925a31_0  pkgs/main
# pandas                         1.1.3  py39h3173b27_2  conda-forge
# pandas                         1.1.3  py39h663e632_0  pkgs/main
# pandas                         1.1.3  py39h6ab05e5_2  conda-forge
# pandas                         1.1.4  py36he38d939_0  conda-forge
# pandas                         1.1.4  py37h08fd248_0  conda-forge
# pandas                         1.1.4  py38h4c96930_0  conda-forge
# pandas                         1.1.4  py39h2e25243_0  conda-forge
# pandas                         1.1.5  py36hd77b12b_0  pkgs/main
# pandas                         1.1.5  py36he38d939_0  conda-forge
# pandas                         1.1.5  py36hf11a4ad_0  pkgs/main
# pandas                         1.1.5  py37h08fd248_0  conda-forge
# pandas                         1.1.5  py37hd77b12b_0  pkgs/main
# pandas                         1.1.5  py37hf11a4ad_0  pkgs/main
# pandas                         1.1.5  py38h4c96930_0  conda-forge
# pandas                         1.1.5  py38hd77b12b_0  pkgs/main
# pandas                         1.1.5  py38hf11a4ad_0  pkgs/main
# pandas                         1.1.5  py39h2e25243_0  conda-forge
# pandas                         1.1.5  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.0  py37h08fd248_0  conda-forge
# pandas                         1.2.0  py37h08fd248_1  conda-forge
# pandas                         1.2.0  py37hf11a4ad_0  pkgs/main
# pandas                         1.2.0  py38h4c96930_0  conda-forge
# pandas                         1.2.0  py38h4c96930_1  conda-forge
# pandas                         1.2.0  py38hf11a4ad_0  pkgs/main
# pandas                         1.2.0  py39h2e25243_0  conda-forge
# pandas                         1.2.0  py39h2e25243_1  conda-forge
# pandas                         1.2.0  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.1  py37h08fd248_0  conda-forge
# pandas                         1.2.1  py37hf11a4ad_0  pkgs/main
# pandas                         1.2.1  py38h4c96930_0  conda-forge
# pandas                         1.2.1  py38hf11a4ad_0  pkgs/main
# pandas                         1.2.1  py39h2e25243_0  conda-forge
# pandas                         1.2.1  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.2  py37h08fd248_0  conda-forge
# pandas                         1.2.2  py37hf11a4ad_0  pkgs/main
# pandas                         1.2.2  py38h4c96930_0  conda-forge
# pandas                         1.2.2  py38hf11a4ad_0  pkgs/main
# pandas                         1.2.2  py39h2e25243_0  conda-forge
# pandas                         1.2.2  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.3  py37h08fd248_0  conda-forge
# pandas                         1.2.3  py37hf11a4ad_0  pkgs/main
# pandas                         1.2.3  py38h4c96930_0  conda-forge
# pandas                         1.2.3  py38hf11a4ad_0  pkgs/main
# pandas                         1.2.3  py39h2e25243_0  conda-forge
# pandas                         1.2.3  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.4  py37h90003fb_0  conda-forge
# pandas                         1.2.4  py37hd77b12b_0  pkgs/main
# pandas                         1.2.4  py37hf11a4ad_0  pkgs/main
# pandas                         1.2.4  py38h60cbd38_0  conda-forge
# pandas                         1.2.4  py38hd77b12b_0  pkgs/main
# pandas                         1.2.4  py38hf11a4ad_0  pkgs/main
# pandas                         1.2.4  py39h2e25243_0  conda-forge
# pandas                         1.2.4  py39hd77b12b_0  pkgs/main
# pandas                         1.2.4  py39hf11a4ad_0  pkgs/main
# pandas                         1.2.5  py37h90003fb_0  conda-forge
# pandas                         1.2.5  py37hd77b12b_0  pkgs/main
# pandas                         1.2.5  py38h60cbd38_0  conda-forge
# pandas                         1.2.5  py38hd77b12b_0  pkgs/main
# pandas                         1.2.5  py39h2e25243_0  conda-forge
# pandas                         1.2.5  py39hd77b12b_0  pkgs/main
# pandas                         1.3.0  py37h90003fb_0  conda-forge
# pandas                         1.3.0  py37hd77b12b_0  pkgs/main
# pandas                         1.3.0  py38h60cbd38_0  conda-forge
# pandas                         1.3.0  py38hd77b12b_0  pkgs/main
# pandas                         1.3.0  py39h2e25243_0  conda-forge
# pandas                         1.3.0  py39hd77b12b_0  pkgs/main
# pandas                         1.3.1  py37h6214cd6_0  pkgs/main
# pandas                         1.3.1  py37h7bc7096_0  conda-forge
# pandas                         1.3.1  py37h90003fb_0  conda-forge
# pandas                         1.3.1  py38h60cbd38_0  conda-forge
# pandas                         1.3.1  py38h6214cd6_0  pkgs/main
# pandas                         1.3.1  py39h2e25243_0  conda-forge
# pandas                         1.3.1  py39h6214cd6_0  pkgs/main
# pandas                         1.3.2  py37h6214cd6_0  pkgs/main
# pandas                         1.3.2  py37h7bc7096_0  conda-forge
# pandas                         1.3.2  py37h9386db6_0  conda-forge
# pandas                         1.3.2  py38h5d928e2_0  conda-forge
# pandas                         1.3.2  py38h6214cd6_0  pkgs/main
# pandas                         1.3.2  py39h2e25243_0  conda-forge
# pandas                         1.3.2  py39h6214cd6_0  pkgs/main
# pandas                         1.3.3  py37h6214cd6_0  pkgs/main
# pandas                         1.3.3  py37h7bc7096_0  conda-forge
# pandas                         1.3.3  py37h9386db6_0  conda-forge
# pandas                         1.3.3  py38h5d928e2_0  conda-forge
# pandas                         1.3.3  py38h6214cd6_0  pkgs/main
# pandas                         1.3.3  py39h2e25243_0  conda-forge
# pandas                         1.3.3  py39h6214cd6_0  pkgs/main
# pandas                         1.3.4 py310hf5e1058_1  conda-forge
# pandas                         1.3.4  py37h6214cd6_0  pkgs/main
# pandas                         1.3.4  py37h7bc7096_0  conda-forge
# pandas                         1.3.4  py37h7bc7096_1  conda-forge
# pandas                         1.3.4  py37h9386db6_0  conda-forge
# pandas                         1.3.4  py37h9386db6_1  conda-forge
# pandas                         1.3.4  py38h5d928e2_0  conda-forge
# pandas                         1.3.4  py38h5d928e2_1  conda-forge
# pandas                         1.3.4  py38h6214cd6_0  pkgs/main
# pandas                         1.3.4  py39h2e25243_0  conda-forge
# pandas                         1.3.4  py39h2e25243_1  conda-forge
# pandas                         1.3.4  py39h6214cd6_0  pkgs/main
# pandas                         1.3.5 py310hf5e1058_0  conda-forge
# pandas                         1.3.5  py37h6214cd6_0  pkgs/main
# pandas                         1.3.5  py37h7bc7096_0  conda-forge
# pandas                         1.3.5  py37h9386db6_0  conda-forge
# pandas                         1.3.5  py38h5d928e2_0  conda-forge
# pandas                         1.3.5  py38h6214cd6_0  pkgs/main
# pandas                         1.3.5  py39h2e25243_0  conda-forge
# pandas                         1.3.5  py39h6214cd6_0  pkgs/main
# pandas                         1.4.0 py310hf5e1058_0  conda-forge
# pandas                         1.4.0  py38h5d928e2_0  conda-forge
# pandas                         1.4.0  py39h2e25243_0  conda-forge
# pandas                         1.4.1 py310hd77b12b_0  pkgs/main
# pandas                         1.4.1 py310hd77b12b_1  pkgs/main
# pandas                         1.4.1 py310hf5e1058_0  conda-forge
# pandas                         1.4.1  py38h5d928e2_0  conda-forge
# pandas                         1.4.1  py38hd77b12b_0  pkgs/main
# pandas                         1.4.1  py38hd77b12b_1  pkgs/main
# pandas                         1.4.1  py39h2e25243_0  conda-forge
# pandas                         1.4.1  py39hd77b12b_0  pkgs/main
# pandas                         1.4.1  py39hd77b12b_1  pkgs/main
# pandas                         1.4.2 py310hd77b12b_0  pkgs/main
# pandas                         1.4.2 py310hf5e1058_0  conda-forge
# pandas                         1.4.2 py310hf5e1058_1  conda-forge
# pandas                         1.4.2 py310hf5e1058_2  conda-forge
# pandas                         1.4.2  py38h50685c1_1  conda-forge
# pandas                         1.4.2  py38h50685c1_2  conda-forge
# pandas                         1.4.2  py38hcc40339_0  conda-forge
# pandas                         1.4.2  py38hcc40339_1  conda-forge
# pandas                         1.4.2  py38hcc40339_2  conda-forge
# pandas                         1.4.2  py38hd77b12b_0  pkgs/main
# pandas                         1.4.2  py39h2e25243_0  conda-forge
# pandas                         1.4.2  py39h2e25243_1  conda-forge
# pandas                         1.4.2  py39h2e25243_2  conda-forge
# pandas                         1.4.2  py39h7b1b8b6_1  conda-forge
# pandas                         1.4.2  py39h7b1b8b6_2  conda-forge
# pandas                         1.4.2  py39hd77b12b_0  pkgs/main
# pandas                         1.4.3 py310hd77b12b_0  pkgs/main
# pandas                         1.4.3 py310hf5e1058_0  conda-forge
# pandas                         1.4.3  py38h50685c1_0  conda-forge
# pandas                         1.4.3  py38hcc40339_0  conda-forge
# pandas                         1.4.3  py38hd77b12b_0  pkgs/main
# pandas                         1.4.3  py39h2e25243_0  conda-forge
# pandas                         1.4.3  py39h7b1b8b6_0  conda-forge
# pandas                         1.4.3  py39hd77b12b_0  pkgs/main
# pandas                         1.4.4 py310h1c4a608_0  conda-forge
# pandas                         1.4.4 py310hd77b12b_0  pkgs/main
# pandas                         1.4.4  py38h0ae2778_0  conda-forge
# pandas                         1.4.4  py38h29d1ec2_0  conda-forge
# pandas                         1.4.4  py38hd77b12b_0  pkgs/main
# pandas                         1.4.4  py39h80a8885_0  conda-forge
# pandas                         1.4.4  py39h86e5caa_0  conda-forge
# pandas                         1.4.4  py39hd77b12b_0  pkgs/main
# pandas                         1.5.0 py310h1c4a608_0  conda-forge
# pandas                         1.5.0  py38h5846ac1_0  conda-forge
# pandas                         1.5.0  py38hc701a83_0  conda-forge
# pandas                         1.5.0  py39h2ba5b7c_0  conda-forge
# pandas                         1.5.0  py39hfed2c35_0  conda-forge
# pandas                         1.5.1 py310h1c4a608_0  conda-forge
# pandas                         1.5.1 py310h1c4a608_1  conda-forge
# pandas                         1.5.1 py310h4ed8f06_0  pkgs/main
# pandas                         1.5.1 py311hf63dbb6_1  conda-forge
# pandas                         1.5.1  py38h5846ac1_0  conda-forge
# pandas                         1.5.1  py38h5846ac1_1  conda-forge
# pandas                         1.5.1  py38hc701a83_0  conda-forge
# pandas                         1.5.1  py38hc701a83_1  conda-forge
# pandas                         1.5.1  py38hf11a4ad_0  pkgs/main
# pandas                         1.5.1  py39h2ba5b7c_0  conda-forge
# pandas                         1.5.1  py39h2ba5b7c_1  conda-forge
# pandas                         1.5.1  py39hf11a4ad_0  pkgs/main
# pandas                         1.5.1  py39hfed2c35_0  conda-forge
# pandas                         1.5.1  py39hfed2c35_1  conda-forge
# pandas                         1.5.2 py310h1c4a608_0  conda-forge
# pandas                         1.5.2 py310h1c4a608_2  conda-forge
# pandas                         1.5.2 py310h4ed8f06_0  pkgs/main
# pandas                         1.5.2 py311heda8569_0  pkgs/main
# pandas                         1.5.2 py311hf63dbb6_0  conda-forge
# pandas                         1.5.2 py311hf63dbb6_2  conda-forge
# pandas                         1.5.2  py38h5846ac1_0  conda-forge
# pandas                         1.5.2  py38h5846ac1_2  conda-forge
# pandas                         1.5.2  py38hc701a83_0  conda-forge
# pandas                         1.5.2  py38hc701a83_1  conda-forge
# pandas                         1.5.2  py38hc701a83_2  conda-forge
# pandas                         1.5.2  py38hf11a4ad_0  pkgs/main
# pandas                         1.5.2  py39h2ba5b7c_0  conda-forge
# pandas                         1.5.2  py39h2ba5b7c_2  conda-forge
# pandas                         1.5.2  py39hf11a4ad_0  pkgs/main
# pandas                         1.5.2  py39hfed2c35_0  conda-forge
# pandas                         1.5.2  py39hfed2c35_1  conda-forge
# pandas                         1.5.2  py39hfed2c35_2  conda-forge
# pandas                         1.5.3 py310h1c4a608_0  conda-forge
# pandas                         1.5.3 py310h1c4a608_1  conda-forge
# pandas                         1.5.3 py310h4ed8f06_0  pkgs/main
# pandas                         1.5.3 py311heda8569_0  pkgs/main
# pandas                         1.5.3 py311hf63dbb6_0  conda-forge
# pandas                         1.5.3 py311hf63dbb6_1  conda-forge
# pandas                         1.5.3  py38h5846ac1_0  conda-forge
# pandas                         1.5.3  py38h5846ac1_1  conda-forge
# pandas                         1.5.3  py38hc701a83_0  conda-forge
# pandas                         1.5.3  py38hc701a83_1  conda-forge
# pandas                         1.5.3  py38hf11a4ad_0  pkgs/main
# pandas                         1.5.3  py39h2ba5b7c_0  conda-forge
# pandas                         1.5.3  py39h2ba5b7c_1  conda-forge
# pandas                         1.5.3  py39hf11a4ad_0  pkgs/main
# pandas                         1.5.3  py39hfed2c35_0  conda-forge
# pandas                         1.5.3  py39hfed2c35_1  conda-forge
# pandas                         2.0.0 py310h1c4a608_0  conda-forge
# pandas                         2.0.0 py311hf63dbb6_0  conda-forge
# pandas                         2.0.0  py38h5846ac1_0  conda-forge
# pandas                         2.0.0  py38hc701a83_0  conda-forge
# pandas                         2.0.0  py39h2ba5b7c_0  conda-forge
# pandas                         2.0.0  py39hfed2c35_0  conda-forge
# pandas                         2.0.1 py310h1c4a608_0  conda-forge
# pandas                         2.0.1 py310h1c4a608_1  conda-forge
# pandas                         2.0.1 py311hf63dbb6_0  conda-forge
# pandas                         2.0.1 py311hf63dbb6_1  conda-forge
# pandas                         2.0.1  py38hda82fe6_0  conda-forge
# pandas                         2.0.1  py38hda82fe6_1  conda-forge
# pandas                         2.0.1  py38hf08cf0d_0  conda-forge
# pandas                         2.0.1  py38hf08cf0d_1  conda-forge
# pandas                         2.0.1  py39h1679cfb_0  conda-forge
# pandas                         2.0.1  py39h1679cfb_1  conda-forge
# pandas                         2.0.1  py39haf6a60e_0  conda-forge
# pandas                         2.0.1  py39haf6a60e_1  conda-forge
# pandas                         2.0.2 py310h1c4a608_0  conda-forge
# pandas                         2.0.2 py311hf63dbb6_0  conda-forge
# pandas                         2.0.2  py38hda82fe6_0  conda-forge
# pandas                         2.0.2  py38hf08cf0d_0  conda-forge
# pandas                         2.0.2  py39h1679cfb_0  conda-forge
# pandas                         2.0.2  py39haf6a60e_0  conda-forge
# pandas                         2.0.3 py310h1c4a608_0  conda-forge
# pandas                         2.0.3 py310h1c4a608_1  conda-forge
# pandas                         2.0.3 py310h4ed8f06_0  pkgs/main
# pandas                         2.0.3 py311hf62ec03_0  pkgs/main
# pandas                         2.0.3 py311hf63dbb6_0  conda-forge
# pandas                         2.0.3 py311hf63dbb6_1  conda-forge
# pandas                         2.0.3  py38h4ed8f06_0  pkgs/main
# pandas                         2.0.3  py38hda82fe6_0  conda-forge
# pandas                         2.0.3  py38hda82fe6_1  conda-forge
# pandas                         2.0.3  py38hf08cf0d_0  conda-forge
# pandas                         2.0.3  py38hf08cf0d_1  conda-forge
# pandas                         2.0.3  py39h1679cfb_0  conda-forge
# pandas                         2.0.3  py39h1679cfb_1  conda-forge
# pandas                         2.0.3  py39h4ed8f06_0  pkgs/main
# pandas                         2.0.3  py39haf6a60e_0  conda-forge
# pandas                         2.0.3  py39haf6a60e_1  conda-forge
# pandas                         2.1.0 py310hecd3228_0  conda-forge
# pandas                         2.1.0 py311hf63dbb6_0  conda-forge
# pandas                         2.1.0  py39h32e6231_0  conda-forge
# pandas                         2.1.1 py310h4ed8f06_0  pkgs/main
# pandas                         2.1.1 py310hecd3228_0  conda-forge
# pandas                         2.1.1 py310hecd3228_1  conda-forge
# pandas                         2.1.1 py311hf62ec03_0  pkgs/main
# pandas                         2.1.1 py311hf63dbb6_0  conda-forge
# pandas                         2.1.1 py311hf63dbb6_1  conda-forge
# pandas                         2.1.1 py312h2ab9e98_1  conda-forge
# pandas                         2.1.1 py312hc7c4135_0  pkgs/main
# pandas                         2.1.1  py39h32e6231_0  conda-forge
# pandas                         2.1.1  py39h32e6231_1  conda-forge
# pandas                         2.1.1  py39h4ed8f06_0  pkgs/main
# pandas                         2.1.1  py39hc3b19f1_1  conda-forge
# pandas                         2.1.2 py310hecd3228_0  conda-forge
# pandas                         2.1.2 py311hf63dbb6_0  conda-forge
# pandas                         2.1.2 py312h2ab9e98_0  conda-forge
# pandas                         2.1.2  py39h32e6231_0  conda-forge
# pandas                         2.1.2  py39hc3b19f1_0  conda-forge
# pandas                         2.1.3 py310hecd3228_0  conda-forge
# pandas                         2.1.3 py311hf63dbb6_0  conda-forge
# pandas                         2.1.3 py312h2ab9e98_0  conda-forge
# pandas                         2.1.3  py39h32e6231_0  conda-forge
# pandas                         2.1.3  py39hc3b19f1_0  conda-forge
# pandas                         2.1.4 py310h4ed8f06_0  pkgs/main
# pandas                         2.1.4 py310hecd3228_0  conda-forge
# pandas                         2.1.4 py311hf62ec03_0  pkgs/main
# pandas                         2.1.4 py311hf63dbb6_0  conda-forge
# pandas                         2.1.4 py312h2ab9e98_0  conda-forge
# pandas                         2.1.4 py312hc7c4135_0  pkgs/main
# pandas                         2.1.4  py39h32e6231_0  conda-forge
# pandas                         2.1.4  py39h4ed8f06_0  pkgs/main
# pandas                         2.1.4  py39hc3b19f1_0  conda-forge
# pandas                         2.2.0 py310hecd3228_0  conda-forge
# pandas                         2.2.0 py311hf63dbb6_0  conda-forge
# pandas                         2.2.0 py312h2ab9e98_0  conda-forge
# pandas                         2.2.0  py39h32e6231_0  conda-forge
# pandas                         2.2.0  py39hc3b19f1_0  conda-forge
# pandas                         2.2.1 py310h5da7b33_0  pkgs/main
# pandas                         2.2.1 py310hecd3228_0  conda-forge
# pandas                         2.2.1 py311hea22821_0  pkgs/main
# pandas                         2.2.1 py311hf63dbb6_0  conda-forge
# pandas                         2.2.1 py312h0158946_0  pkgs/main
# pandas                         2.2.1 py312h2ab9e98_0  conda-forge
# pandas                         2.2.1  py39h32e6231_0  conda-forge
# pandas                         2.2.1  py39h5da7b33_0  pkgs/main
# pandas                         2.2.1  py39hc3b19f1_0  conda-forge
# pandas                         2.2.2 py310h5da7b33_0  pkgs/main
# pandas                         2.2.2 py310hb4db72f_1  conda-forge
# pandas                         2.2.2 py310hecd3228_0  conda-forge
# pandas                         2.2.2 py311hcf9f919_1  conda-forge
# pandas                         2.2.2 py311hea22821_0  pkgs/main
# pandas                         2.2.2 py311hf63dbb6_0  conda-forge
# pandas                         2.2.2 py312h0158946_0  pkgs/main
# pandas                         2.2.2 py312h2ab9e98_0  conda-forge
# pandas                         2.2.2 py312h72972c8_1  conda-forge
# pandas                         2.2.2  py39h0d2a915_1  conda-forge
# pandas                         2.2.2  py39h2366fc2_1  conda-forge
# pandas                         2.2.2  py39h32e6231_0  conda-forge
# pandas                         2.2.2  py39h5da7b33_0  pkgs/main
# pandas                         2.2.2  py39hc3b19f1_0  conda-forge
# pandas                         2.2.3 py310h5da7b33_0  pkgs/main
# pandas                         2.2.3 py310hb4db72f_0  conda-forge
# pandas                         2.2.3 py310hb4db72f_1  conda-forge
# pandas                         2.2.3 py310hb4db72f_3  conda-forge
# pandas                         2.2.3 py311h5da7b33_0  pkgs/main
# pandas                         2.2.3 py311hcf9f919_0  conda-forge
# pandas                         2.2.3 py311hcf9f919_1  conda-forge
# pandas                         2.2.3 py311hcf9f919_3  conda-forge
# pandas                         2.2.3 py312h5da7b33_0  pkgs/main
# pandas                         2.2.3 py312h72972c8_0  conda-forge
# pandas                         2.2.3 py312h72972c8_1  conda-forge
# pandas                         2.2.3 py312h72972c8_3  conda-forge
# pandas                         2.2.3 py313h5da7b33_0  pkgs/main
# pandas                         2.2.3 py313hf91d08e_1  conda-forge
# pandas                         2.2.3 py313hf91d08e_3  conda-forge
# pandas                         2.2.3  py39h2366fc2_0  conda-forge
# pandas                         2.2.3  py39h2366fc2_1  conda-forge
# pandas                         2.2.3  py39h2366fc2_2  conda-forge
# pandas                         2.2.3  py39h2366fc2_3  conda-forge
# pandas                         2.2.3  py39h5da7b33_0  pkgs/main
# pandas                         2.3.0 py310hb4db72f_0  conda-forge
# pandas                         2.3.0 py311hcf9f919_0  conda-forge
# pandas                         2.3.0 py312h72972c8_0  conda-forge
# pandas                         2.3.0 py313hf91d08e_0  conda-forge
# pandas                         2.3.0  py39h2366fc2_0  conda-forge
# pandas                         2.3.1 py310h885b0b7_0  pkgs/main
# pandas                         2.3.1 py310hed136d8_0  conda-forge
# pandas                         2.3.1 py311h11fd7f3_0  conda-forge
# pandas                         2.3.1 py311h885b0b7_0  pkgs/main
# pandas                         2.3.1 py312h885b0b7_0  pkgs/main
# pandas                         2.3.1 py312hc128f0a_0  conda-forge
# pandas                         2.3.1 py313h885b0b7_0  pkgs/main
# pandas                         2.3.1 py313hc90dcd4_0  conda-forge
# pandas                         2.3.1  py39h743b7ac_0  conda-forge
# pandas                         2.3.1  py39h885b0b7_0  pkgs/main
# pandas                         2.3.2 py310ha5e6156_0  pkgs/main
# pandas                         2.3.2 py310hed136d8_0  conda-forge
# pandas                         2.3.2 py311h11fd7f3_0  conda-forge
# pandas                         2.3.2 py311ha5e6156_0  pkgs/main
# pandas                         2.3.2 py312ha5e6156_0  pkgs/main
# pandas                         2.3.2 py312hc128f0a_0  conda-forge
# pandas                         2.3.2 py313h42c1672_0  pkgs/main
# pandas                         2.3.2 py313hc90dcd4_0  conda-forge
# pandas                         2.3.2  py39ha5e6156_0  pkgs/main
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![image.png](attachment:image.png)
