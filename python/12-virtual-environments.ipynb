# %% [markdown]
# # Virtuelle Umgebungen

# %% [markdown]
# ## Venv

# %%
# %%python -m venv ./data/my_env
# %%source ./data/my_env/Scripts/activate.bat # For Windows
# #%%source ./data/my_env/bin/activate # For Linux or MacOS
#
# # To use the virtual environment in Jupyter Notebooks
# %%pip install ipykernel
# %%python -m ipykernel install --user --name=my_env --display-name "Python (my_env)"

# %%
import sys
print(sys.prefix)
print(sys.base_prefix)
# Out:
# c:\Workspace\DataScience\python\data\my_env
# c:\Program Files\Python311

# %% [markdown]
# ## Anaconda

# %%
# %conda --version
# Out:
# conda 25.7.0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda info
# Out:
#      active environment : base
#     active env location : C:\Users\bzenz\AppData\Local\miniconda3
#             shell level : 1
#        user config file : C:\Users\bzenz\.condarc
#  populated config files : C:\Users\bzenz\AppData\Local\miniconda3\.condarc
#           conda version : 25.7.0
#     conda-build version : not installed
#          python version : 3.13.5.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=25.7.0=0
#                           __cuda=12.8=0
#                           __win=10.0.19045=0
#        base environment : C:\Users\bzenz\AppData\Local\miniconda3  (writable)
#       conda av data dir : C:\Users\bzenz\AppData\Local\miniconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
# ...

# %%
# %conda update conda
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Automatische Erkennung aller Envs in Jupyter:

# %%
# %conda install -n base nb_conda_kernels -y
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\bzenz\AppData\Local\miniconda3
#
#   added / updated specs:
#     - nb_conda_kernels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nb_conda_kernels-2.5.2     |  py313haa95532_1          46 KB
#     ------------------------------------------------------------
#                                            Total:          46 KB
#
# The following NEW packages will be INSTALLED:
#
#   nb_conda_kernels   pkgs/main/win-64::nb_conda_kernels-2.5.2-py313haa95532_1
#
#
#
# ...
# nb_conda_kernels-2.5 | 46 KB     |            |   0%
# nb_conda_kernels-2.5 | 46 KB     | ###4       |  35%
# nb_conda_kernels-2.5 | 46 KB     | ########## | 100%
# nb_conda_kernels-2.5 | 46 KB     | ########## | 100%
#
#  done
# ...

# %%
# %conda create --clone base --name testenv
# Out:
# 3 channel Terms of Service accepted
# Source:      C:\Users\bzenz\AppData\Local\miniconda3
# Destination: C:\Users\bzenz\AppData\Local\miniconda3\envs\testenv
# Packages: 134
# Files: 8
#
# ...
# anaconda_powershell_ |            |   0%
#
# anaconda_prompt-1.1. |            |   0%
#
#
# ca-certificates-2025 |            |   0%
#
#
#
# nlohmann_json-3.11.2 |            |   0%
#
#
#
#
# pybind11-abi-5       |            |   0%
#
#
#
#
#
# tzdata-2025b         |            |   0%
#
#
#
#
#
#
# ucrt-10.0.22621.0    |            |   0%
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 |            |   0%
#
#
#
#
#
#
#
#
# vc-14.3              |            |   0%
#
#
#
#
#
#
#
#
#
# vs2015_runtime-14.44 |            |   0%
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.7.1          |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# fmt-9.1.0            |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# Für mich hat aber das hier besser funktioniert:

# %%
# %conda config --add channels conda-forge
# %conda config --set channel_priority strict
# %conda create -n py312 -c conda-forge python=3.12 numpy

# %%
# %conda env list
# Out:
# # conda environments:
# #
# base                 * C:\Users\bzenz\AppData\Local\miniconda3
# testenv                C:\Users\bzenz\AppData\Local\miniconda3\envs\testenv
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda init # To initialize conda for the current shell (does not work in Jupyter Notebooks)
# Out:
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Scripts\conda.exe
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Scripts\conda-env.exe
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Scripts\conda-script.py
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Scripts\conda-env-script.py
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\conda.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Library\bin\conda.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\_conda_activate.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\rename_tmp.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\conda_auto_activate.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\conda_hook.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\Scripts\activate.bat
# no change     C:\Users\bzenz\AppData\Local\miniconda3\condabin\activate.bat
# ...

# %%
# %conda activate testenv # Does not work in Jupyter Notebooks
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
# %conda install numpy pandas scipy statsmodels scikit-learn matplotlib -y
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\bzenz\AppData\Local\miniconda3\envs\py312
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#     - scipy
#     - statsmodels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          48 KB  conda-forge
#     brotli-1.1.0               |       hfd05255_4          20 KB  conda-forge
#     brotli-bin-1.1.0           |       hfd05255_4          21 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     contourpy-1.3.3            |  py312hf90b1b7_2         220 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
# ...

# %%
# %conda env export --name py312 > ./data/py312_environment.yml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %conda env create -f ./data/py312_environment.yml
